# %%
cd ..
# Out:
# /Users/satouwataru/Desktop/DiveIntoCode/git/diveintocode-ml/GraduationWork/v3/codes

# %%
cd ..
# Out:
# /Users/satouwataru/Desktop/DiveIntoCode/git/diveintocode-ml/GraduationWork/v3

# %%
import numpy as np
import pandas as pd
import optuna.integration.lightgbm as lgb_o
from sklearn.metrics import mean_squared_error

import preprocessing
from right_gbm import my_model as my_right_gbm
from some_models import my_model as some_model
from sklearn.model_selection import train_test_split

def pred_toto(toto_n, toto_kind):

    df_toto_preds = get_y_preds(toto_n, toto_kind)
    yyyyMMdd = df_toto_preds.min(axis=0)['開催日']

    df_y_preds = pd.read_csv('data/model/y_preds_par_year.csv', index_col=0).reset_index(drop = True)
    df_y_preds = df_y_preds[df_y_preds['開催日'] < yyyyMMdd]

    df_toto = pd.read_csv('data/marge/toto_info.csv', index_col=0).reset_index(drop = True)
    df_toto = df_toto[['第n回', '種別', '開催日', 'ホーム', 'アウェイ', 'くじ結果'] ]
    df_toto = df_toto[df_toto['くじ結果'] != '102'].reset_index(drop = True)

    drop_columns = ['第n回', '種別','is_even_1_1_lgbm', 'is_lose_1_1_lgbm', 'w_e_l_2_2_lgbm' ]
    train = pd.merge(df_y_preds, df_toto).drop(columns = drop_columns)
    test = df_toto_preds.drop(columns = drop_columns)

    train = preprocessing.team_to_index(train, 'ホーム')
    train = preprocessing.team_to_index(train, 'アウェイ')
    test = preprocessing.team_to_index(test, 'ホーム')
    test = preprocessing.team_to_index(test, 'アウェイ')

    category_columns = ['ホーム', 'アウェイ']
    for column in category_columns:
        train[column] = pd.Series(train[column]).astype('category')
        test[column] = pd.Series(test[column]).astype('category')

    train, val = train_test_split(train, train_size=0.8)

    x_train = train.drop(columns = ['くじ結果'])
    y_train = train['くじ結果'].values
    x_val = val.drop(columns = ['くじ結果'])
    y_val = val['くじ結果'].values
    x_test = test
#     return x_train, x_val, y_train, y_val
    model = model_toto()
    model.fit(x_train, x_val, y_train, y_val)
    y_pred, y_pred_proba = model.predict(x_test)

    df_pred = pd.DataFrame(y_pred_proba, columns=['分', '勝', '敗'])
    df_toto = x_test[['開催日', 'ホーム', 'アウェイ']]
    df_result = pd.concat([df_pred, df_toto], axis=1)
    df_result = preprocessing.index_to_team(df_result, 'ホーム')
    df_result = preprocessing.index_to_team(df_result, 'アウェイ')

    df_result = df_result.reindex(columns=['開催日', 'ホーム', 'アウェイ', '勝', '敗', '分'])

    return df_result

def get_y_preds(toto_n, toto_kind):
    
    df = preprocessing.preprocessing(toto_n, toto_kind)
    yyyyMMdd = df[df['train_test'] == 'toto'].iloc[:1]['年月日'].values[0]
    year = str(yyyyMMdd)[:4]
    # 予測値を算出(right_gbm)
    df_result, df_acuracy = my_right_gbm.predict_toto(year)
    df_result = preprocessing.index_to_team(df_result, 'H_Team')
    df_result = preprocessing.index_to_team(df_result, 'A_Team')
    df_result['toto_n'] = toto_n
    df_result['toto_kind'] = toto_kind
    
    # 予測値を算出(some_models)
#     df_result2 = some_model.predict_toto()
#     df_result2 = preprocessing.index_to_team(df_result2, 'H_Team')
#     df_result2 = preprocessing.index_to_team(df_result2, 'A_Team')
#     df_result2['toto_n'] = toto_n
#     df_result2['toto_kind'] = toto_kind
#     df_result = pd.merge(df_result, df_result2)

    # 結果を整形
    df_y_preds = pd.read_csv('data/model/y_preds_par_year.csv', index_col=0).reset_index(drop = True)
    df_toto = pd.read_csv('data/marge/toto_info.csv', index_col=0).reset_index(drop = True)
    df_toto = df_toto[['第n回', '種別', '開催日', 'ホーム', 'アウェイ']]

    df_marge = pd.merge(df_toto, df_result, 
                 left_on=['第n回', '種別', 'ホーム'],
                 right_on=['toto_n', 'toto_kind', 'H_Team']).drop(columns = ['H_Team', 'A_Team', '年月日', 'toto_n', 'toto_kind'])

    df_y_preds = pd.concat([df_y_preds, df_marge])
    df_y_preds = df_y_preds.drop_duplicates(['第n回', 'ホーム', 'アウェイ'], keep='last').reset_index(drop = True)
    df_y_preds.to_csv("data/model/y_preds_par_year.csv")

    return df_marge
    
class model_toto:
    
    def fit(self, x_train, x_val, y_train, y_val):
        
        lgb_train = lgb_o.Dataset(x_train, y_train)
        lgb_eval = lgb_o.Dataset(x_val, y_val) 
        # 学習用パラメータ
        lgbm_params = {
            'objective': 'multiclass',
            'metric': 'multi_logloss',
            'num_class': 3,
            'verbosity': -1
        }
        # 学習
        model = lgb_o.train(lgbm_params,
                        lgb_train,
                        valid_sets=lgb_eval,
                        early_stopping_rounds=100,
                        verbose_eval=200,)
        self.model = model

        y_pred_proba = self.model.predict(x_val, num_iteration=self.model.best_iteration)
        y_pred = np.argmax(y_pred_proba, axis=1)

        # Accuracy の計算
        accuracy = sum(y_val == y_pred) / len(y_val)
        print('accuracy:', accuracy)
        
        return y_pred, y_pred_proba, accuracy
    
    def predict(self, x_test):
        y_pred_proba = self.model.predict(x_test, num_iteration=self.model.best_iteration)
        y_pred = np.argmax(y_pred_proba, axis=1)
        return y_pred, y_pred_proba

# %%
df_toto = pd.read_csv('data/marge/toto_info.csv', index_col=0).reset_index(drop = True)
df_toto = df_toto[df_toto['開催日'] > 20130000]
df_toto = df_toto[df_toto['種別'] == 'toto']
df_toto = df_toto[['第n回', '種別']].drop_duplicates().reset_index(drop = True)

# %%
for i, row in df_toto.iterrows():
    toto_n = row['第n回']
    toto_kind = row['種別']
    if toto_n < 0:
        continue
    try:
        print(toto_n, toto_kind)
        df_toto_preds = get_y_preds(toto_n, toto_kind)
    except:
        continue
# Out:
# 609 toto
# <ipython-input-5-7ab00576a4f2>:8: DtypeWarning: Columns (12,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   df_toto_preds = get_y_preds(toto_n, toto_kind)
# [I 2021-05-12 16:23:29,431] A new study created in memory with name: no-name-3532a633-26d1-4140-8bea-629def66610b
# feature_fraction, val_score: 0.387242:  14%|#4        | 1/7 [00:00<00:00,  9.29it/s][I 2021-05-12 16:23:29,550] Trial 0 finished with value: 0.38724163785949545 and parameters: {'feature_fraction': 0.7}. Best is trial 0 with value: 0.38724163785949545.
# feature_fraction, val_score: 0.387242:  14%|#4        | 1/7 [00:00<00:00,  9.29it/s][I 2021-05-12 16:23:29,636] Trial 1 finished with value: 0.39345364149124273 and parameters: {'feature_fraction': 0.4}. Best is trial 0 with value: 0.38724163785949545.
# feature_fraction, val_score: 0.387242:  29%|##8       | 2/7 [00:00<00:00,  9.29it/s]
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [24]	valid_0's multi_logloss: 0.387242
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [44]	valid_0's multi_logloss: 0.393454
# Training until validation scores don't improve for 100 rounds
# feature_fraction, val_score: 0.377631:  43%|####2     | 3/7 [00:00<00:00,  9.13it/s][I 2021-05-12 16:23:29,770] Trial 2 finished with value: 0.3776309414843946 and parameters: {'feature_fraction': 1.0}. Best is trial 2 with value: 0.3776309414843946.
# feature_fraction, val_score: 0.377631:  57%|#####7    | 4/7 [00:00<00:00,  8.36it/s][I 2021-05-12 16:23:29,909] Trial 3 finished with value: 0.3859519935684503 and parameters: {'feature_fraction': 0.8}. Best is trial 2 with value: 0.3776309414843946.
# feature_fraction, val_score: 0.377631:  57%|#####7    | 4/7 [00:00<00:00,  8.36it/s]
# Early stopping, best iteration is:
# [32]	valid_0's multi_logloss: 0.377631
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [39]	valid_0's multi_logloss: 0.385952
# Training until validation scores don't improve for 100 rounds
# feature_fraction, val_score: 0.377631:  71%|#######1  | 5/7 [00:00<00:00,  7.78it/s][I 2021-05-12 16:23:30,056] Trial 4 finished with value: 0.3844330627915036 and parameters: {'feature_fraction': 0.5}. Best is trial 2 with value: 0.3776309414843946.
# feature_fraction, val_score: 0.377631:  86%|########5 | 6/7 [00:00<00:00,  7.95it/s][I 2021-05-12 16:23:30,176] Trial 5 finished with value: 0.38231477202517733 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 2 with value: 0.3776309414843946.
# feature_fraction, val_score: 0.377631:  86%|########5 | 6/7 [00:00<00:00,  7.95it/s]
# Early stopping, best iteration is:
# [47]	valid_0's multi_logloss: 0.384433
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [39]	valid_0's multi_logloss: 0.382315
# Training until validation scores don't improve for 100 rounds
# feature_fraction, val_score: 0.377631: 100%|##########| 7/7 [00:00<00:00,  7.97it/s][I 2021-05-12 16:23:30,301] Trial 6 finished with value: 0.37905933564342875 and parameters: {'feature_fraction': 0.6}. Best is trial 2 with value: 0.3776309414843946.
# feature_fraction, val_score: 0.377631: 100%|##########| 7/7 [00:00<00:00,  8.14it/s]
# num_leaves, val_score: 0.377631:   5%|5         | 1/20 [00:00<00:02,  6.73it/s][I 2021-05-12 16:23:30,454] Trial 7 finished with value: 0.3776309414843946 and parameters: {'num_leaves': 84}. Best is trial 7 with value: 0.3776309414843946.
# num_leaves, val_score: 0.377631:   5%|5         | 1/20 [00:00<00:02,  6.73it/s]
# Early stopping, best iteration is:
# [38]	valid_0's multi_logloss: 0.379059
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [32]	valid_0's multi_logloss: 0.377631
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.377631:  10%|#         | 2/20 [00:00<00:03,  5.51it/s][I 2021-05-12 16:23:30,659] Trial 8 finished with value: 0.3776309414843946 and parameters: {'num_leaves': 33}. Best is trial 7 with value: 0.3776309414843946.
# num_leaves, val_score: 0.377631:  15%|#5        | 3/20 [00:00<00:02,  6.47it/s][I 2021-05-12 16:23:30,781] Trial 9 finished with value: 0.3776309414843946 and parameters: {'num_leaves': 20}. Best is trial 7 with value: 0.3776309414843946.
# num_leaves, val_score: 0.377631:  15%|#5        | 3/20 [00:00<00:02,  6.47it/s]
# Early stopping, best iteration is:
# [32]	valid_0's multi_logloss: 0.377631
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [32]	valid_0's multi_logloss: 0.377631
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.377631:  20%|##        | 4/20 [00:00<00:02,  6.84it/s][I 2021-05-12 16:23:30,914] Trial 10 finished with value: 0.3776309414843946 and parameters: {'num_leaves': 235}. Best is trial 7 with value: 0.3776309414843946.
# num_leaves, val_score: 0.377631:  20%|##        | 4/20 [00:00<00:02,  6.84it/s]
# Early stopping, best iteration is:
# [32]	valid_0's multi_logloss: 0.377631
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.377631:  25%|##5       | 5/20 [00:00<00:02,  5.19it/s][I 2021-05-12 16:23:31,190] Trial 11 finished with value: 0.3776309414843946 and parameters: {'num_leaves': 139}. Best is trial 7 with value: 0.3776309414843946.
# num_leaves, val_score: 0.377631:  30%|###       | 6/20 [00:01<00:02,  5.59it/s][I 2021-05-12 16:23:31,342] Trial 12 finished with value: 0.3776309414843946 and parameters: {'num_leaves': 135}. Best is trial 7 with value: 0.3776309414843946.
# num_leaves, val_score: 0.377631:  30%|###       | 6/20 [00:01<00:02,  5.59it/s]
# Early stopping, best iteration is:
# [32]	valid_0's multi_logloss: 0.377631
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [32]	valid_0's multi_logloss: 0.377631
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.377631:  35%|###5      | 7/20 [00:01<00:02,  5.92it/s][I 2021-05-12 16:23:31,490] Trial 13 finished with value: 0.3776309414843946 and parameters: {'num_leaves': 67}. Best is trial 7 with value: 0.3776309414843946.
# num_leaves, val_score: 0.377631:  40%|####      | 8/20 [00:01<00:01,  6.51it/s][I 2021-05-12 16:23:31,611] Trial 14 finished with value: 0.3776309414843946 and parameters: {'num_leaves': 233}. Best is trial 7 with value: 0.3776309414843946.
# num_leaves, val_score: 0.377631:  40%|####      | 8/20 [00:01<00:01,  6.51it/s]
# Early stopping, best iteration is:
# [32]	valid_0's multi_logloss: 0.377631
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [32]	valid_0's multi_logloss: 0.377631
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.377631:  45%|####5     | 9/20 [00:01<00:01,  6.72it/s][I 2021-05-12 16:23:31,749] Trial 15 finished with value: 0.3776309414843946 and parameters: {'num_leaves': 35}. Best is trial 7 with value: 0.3776309414843946.
# num_leaves, val_score: 0.377631:  50%|#####     | 10/20 [00:01<00:01,  7.20it/s][I 2021-05-12 16:23:31,865] Trial 16 finished with value: 0.3776309414843946 and parameters: {'num_leaves': 52}. Best is trial 7 with value: 0.3776309414843946.
# num_leaves, val_score: 0.377631:  50%|#####     | 10/20 [00:01<00:01,  7.20it/s]
# Early stopping, best iteration is:
# [32]	valid_0's multi_logloss: 0.377631
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [32]	valid_0's multi_logloss: 0.377631
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.377631:  55%|#####5    | 11/20 [00:01<00:01,  7.29it/s][I 2021-05-12 16:23:31,999] Trial 17 finished with value: 0.3776309414843946 and parameters: {'num_leaves': 97}. Best is trial 7 with value: 0.3776309414843946.
# num_leaves, val_score: 0.377631:  55%|#####5    | 11/20 [00:01<00:01,  7.29it/s][I 2021-05-12 16:23:32,093] Trial 18 finished with value: 0.3776309414843946 and parameters: {'num_leaves': 95}. Best is trial 7 with value: 0.3776309414843946.
# num_leaves, val_score: 0.354050:  65%|######5   | 13/20 [00:01<00:00,  9.43it/s][I 2021-05-12 16:23:32,140] Trial 19 finished with value: 0.35405015128349393 and parameters: {'num_leaves': 4}. Best is trial 19 with value: 0.35405015128349393.
# num_leaves, val_score: 0.354050:  65%|######5   | 13/20 [00:01<00:00,  9.43it/s]
# Early stopping, best iteration is:
# [32]	valid_0's multi_logloss: 0.377631
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [32]	valid_0's multi_logloss: 0.377631
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [38]	valid_0's multi_logloss: 0.35405
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.354050:  70%|#######   | 14/20 [00:02<00:00,  6.92it/s][I 2021-05-12 16:23:32,400] Trial 20 finished with value: 0.3776309414843946 and parameters: {'num_leaves': 183}. Best is trial 19 with value: 0.35405015128349393.
# num_leaves, val_score: 0.354050:  70%|#######   | 14/20 [00:02<00:00,  6.92it/s][I 2021-05-12 16:23:32,454] Trial 21 finished with value: 0.36853519035280197 and parameters: {'num_leaves': 2}. Best is trial 19 with value: 0.35405015128349393.
# num_leaves, val_score: 0.354050:  80%|########  | 16/20 [00:02<00:00,  9.18it/s][I 2021-05-12 16:23:32,518] Trial 22 finished with value: 0.35405015128349393 and parameters: {'num_leaves': 4}. Best is trial 19 with value: 0.35405015128349393.
# num_leaves, val_score: 0.354050:  80%|########  | 16/20 [00:02<00:00,  9.18it/s]
# Early stopping, best iteration is:
# [32]	valid_0's multi_logloss: 0.377631
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's multi_logloss: 0.370847
# Early stopping, best iteration is:
# [102]	valid_0's multi_logloss: 0.368535
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [38]	valid_0's multi_logloss: 0.35405
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [37]	valid_0's multi_logloss: 0.389132
# num_leaves, val_score: 0.354050:  80%|########  | 16/20 [00:02<00:00,  9.18it/s][I 2021-05-12 16:23:32,597] Trial 23 finished with value: 0.38913228668953204 and parameters: {'num_leaves': 8}. Best is trial 19 with value: 0.35405015128349393.
# num_leaves, val_score: 0.354050:  90%|######### | 18/20 [00:02<00:00, 10.96it/s][I 2021-05-12 16:23:32,641] Trial 24 finished with value: 0.36853519035280197 and parameters: {'num_leaves': 2}. Best is trial 19 with value: 0.35405015128349393.
# num_leaves, val_score: 0.354050:  90%|######### | 18/20 [00:02<00:00, 10.96it/s][I 2021-05-12 16:23:32,731] Trial 25 finished with value: 0.3776309414843946 and parameters: {'num_leaves': 184}. Best is trial 19 with value: 0.35405015128349393.
# num_leaves, val_score: 0.354050:  95%|#########5| 19/20 [00:02<00:00, 10.96it/s]
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's multi_logloss: 0.370847
# Early stopping, best iteration is:
# [102]	valid_0's multi_logloss: 0.368535
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [32]	valid_0's multi_logloss: 0.377631
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.354050: 100%|##########| 20/20 [00:02<00:00,  8.56it/s][I 2021-05-12 16:23:32,971] Trial 26 finished with value: 0.3776309414843946 and parameters: {'num_leaves': 55}. Best is trial 19 with value: 0.35405015128349393.
# num_leaves, val_score: 0.354050: 100%|##########| 20/20 [00:02<00:00,  7.50it/s]
# bagging, val_score: 0.354050:   0%|          | 0/10 [00:00<?, ?it/s][I 2021-05-12 16:23:33,031] Trial 27 finished with value: 0.3630579316772887 and parameters: {'bagging_fraction': 0.7807207231029506, 'bagging_freq': 4}. Best is trial 27 with value: 0.3630579316772887.
# bagging, val_score: 0.354050:  20%|##        | 2/10 [00:00<00:00, 18.73it/s][I 2021-05-12 16:23:33,082] Trial 28 finished with value: 0.36261334149842644 and parameters: {'bagging_fraction': 0.48753210247201756, 'bagging_freq': 6}. Best is trial 28 with value: 0.36261334149842644.
# bagging, val_score: 0.354050:  20%|##        | 2/10 [00:00<00:00, 18.73it/s][I 2021-05-12 16:23:33,137] Trial 29 finished with value: 0.35405015128349393 and parameters: {'bagging_fraction': 0.9991604058908685, 'bagging_freq': 5}. Best is trial 29 with value: 0.35405015128349393.
# bagging, val_score: 0.354050:  30%|###       | 3/10 [00:00<00:00, 18.73it/s]
# Early stopping, best iteration is:
# [32]	valid_0's multi_logloss: 0.377631
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [48]	valid_0's multi_logloss: 0.363058
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [50]	valid_0's multi_logloss: 0.362613
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [38]	valid_0's multi_logloss: 0.35405
# Training until validation scores don't improve for 100 rounds
# bagging, val_score: 0.354050:  40%|####      | 4/10 [00:00<00:00, 11.05it/s][I 2021-05-12 16:23:33,315] Trial 30 finished with value: 0.35962867603411075 and parameters: {'bagging_fraction': 0.6781940763182561, 'bagging_freq': 2}. Best is trial 29 with value: 0.35405015128349393.
# bagging, val_score: 0.354050:  40%|####      | 4/10 [00:00<00:00, 11.05it/s][I 2021-05-12 16:23:33,366] Trial 31 finished with value: 0.3744057834462545 and parameters: {'bagging_fraction': 0.6403246445794648, 'bagging_freq': 1}. Best is trial 29 with value: 0.35405015128349393.
# bagging, val_score: 0.354050:  60%|######    | 6/10 [00:00<00:00, 12.96it/s][I 2021-05-12 16:23:33,438] Trial 32 finished with value: 0.4024253517344485 and parameters: {'bagging_fraction': 0.6451503697564241, 'bagging_freq': 7}. Best is trial 29 with value: 0.35405015128349393.
# bagging, val_score: 0.354050:  60%|######    | 6/10 [00:00<00:00, 12.96it/s][I 2021-05-12 16:23:33,507] Trial 33 finished with value: 0.3717673751535535 and parameters: {'bagging_fraction': 0.5157488217324491, 'bagging_freq': 2}. Best is trial 29 with value: 0.35405015128349393.
# bagging, val_score: 0.354050:  70%|#######   | 7/10 [00:00<00:00, 12.96it/s]
# Early stopping, best iteration is:
# [56]	valid_0's multi_logloss: 0.359629
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [35]	valid_0's multi_logloss: 0.374406
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [44]	valid_0's multi_logloss: 0.402425
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [56]	valid_0's multi_logloss: 0.371767
# bagging, val_score: 0.354050:  80%|########  | 8/10 [00:00<00:00, 13.60it/s][I 2021-05-12 16:23:33,574] Trial 34 finished with value: 0.38113530950441415 and parameters: {'bagging_fraction': 0.6164132731208554, 'bagging_freq': 1}. Best is trial 29 with value: 0.35405015128349393.
# bagging, val_score: 0.354050:  80%|########  | 8/10 [00:00<00:00, 13.60it/s][I 2021-05-12 16:23:33,632] Trial 35 finished with value: 0.3709266346857336 and parameters: {'bagging_fraction': 0.7655114281940554, 'bagging_freq': 7}. Best is trial 29 with value: 0.35405015128349393.
# bagging, val_score: 0.353582: 100%|##########| 10/10 [00:00<00:00, 14.84it/s][I 2021-05-12 16:23:33,686] Trial 36 finished with value: 0.3535818119020613 and parameters: {'bagging_fraction': 0.952344896499395, 'bagging_freq': 3}. Best is trial 36 with value: 0.3535818119020613.
# bagging, val_score: 0.353582: 100%|##########| 10/10 [00:00<00:00, 14.03it/s]
# feature_fraction_stage2, val_score: 0.353582:   0%|          | 0/3 [00:00<?, ?it/s]
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [50]	valid_0's multi_logloss: 0.381135
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [41]	valid_0's multi_logloss: 0.370927
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [39]	valid_0's multi_logloss: 0.353582
# Training until validation scores don't improve for 100 rounds
# feature_fraction_stage2, val_score: 0.349046:   0%|          | 0/3 [00:00<?, ?it/s][I 2021-05-12 16:23:33,749] Trial 37 finished with value: 0.34904643955669623 and parameters: {'feature_fraction': 0.9840000000000001}. Best is trial 37 with value: 0.34904643955669623.
# feature_fraction_stage2, val_score: 0.349046:  67%|######6   | 2/3 [00:00<00:00, 18.43it/s][I 2021-05-12 16:23:33,799] Trial 38 finished with value: 0.3555721531906075 and parameters: {'feature_fraction': 0.92}. Best is trial 37 with value: 0.34904643955669623.
# feature_fraction_stage2, val_score: 0.349046:  67%|######6   | 2/3 [00:00<00:00, 18.43it/s][I 2021-05-12 16:23:33,853] Trial 39 finished with value: 0.35842635339322765 and parameters: {'feature_fraction': 0.9520000000000001}. Best is trial 37 with value: 0.34904643955669623.
# feature_fraction_stage2, val_score: 0.349046: 100%|##########| 3/3 [00:00<00:00, 18.20it/s]
# regularization_factors, val_score: 0.349046:   0%|          | 0/20 [00:00<?, ?it/s][I 2021-05-12 16:23:33,922] Trial 40 finished with value: 0.3491159643080686 and parameters: {'lambda_l1': 0.008578922509495468, 'lambda_l2': 0.006609409381710101}. Best is trial 40 with value: 0.3491159643080686.
# regularization_factors, val_score: 0.349046:   5%|5         | 1/20 [00:00<00:01, 15.08it/s]
# Early stopping, best iteration is:
# [42]	valid_0's multi_logloss: 0.349046
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [40]	valid_0's multi_logloss: 0.355572
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [43]	valid_0's multi_logloss: 0.358426
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [42]	valid_0's multi_logloss: 0.349116
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 0.349046:  10%|#         | 2/20 [00:00<00:01, 16.33it/s][I 2021-05-12 16:23:33,980] Trial 41 finished with value: 0.3490654912715376 and parameters: {'lambda_l1': 0.002587224882981298, 'lambda_l2': 0.0015086482573967363}. Best is trial 41 with value: 0.3490654912715376.
# regularization_factors, val_score: 0.349046:  10%|#         | 2/20 [00:00<00:01, 16.33it/s][I 2021-05-12 16:23:34,040] Trial 42 finished with value: 0.35536206774613227 and parameters: {'lambda_l1': 2.063170386040332, 'lambda_l2': 2.271647564144547e-05}. Best is trial 41 with value: 0.3490654912715376.
# regularization_factors, val_score: 0.349046:  15%|#5        | 3/20 [00:00<00:01, 16.33it/s]
# Early stopping, best iteration is:
# [42]	valid_0's multi_logloss: 0.349065
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [72]	valid_0's multi_logloss: 0.355362
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 0.349046:  20%|##        | 4/20 [00:00<00:01, 10.07it/s][I 2021-05-12 16:23:34,232] Trial 43 finished with value: 0.3490562400846275 and parameters: {'lambda_l1': 3.795324285711479e-05, 'lambda_l2': 0.002415696221310663}. Best is trial 43 with value: 0.3490562400846275.
# regularization_factors, val_score: 0.349046:  20%|##        | 4/20 [00:00<00:01, 10.07it/s][I 2021-05-12 16:23:34,314] Trial 44 finished with value: 0.3515873399512492 and parameters: {'lambda_l1': 0.1242163590594552, 'lambda_l2': 5.276665166093255e-07}. Best is trial 43 with value: 0.3490562400846275.
# regularization_factors, val_score: 0.349046:  30%|###       | 6/20 [00:00<00:01, 11.14it/s][I 2021-05-12 16:23:34,389] Trial 45 finished with value: 0.34904708530346723 and parameters: {'lambda_l1': 0.0001279453373344878, 'lambda_l2': 1.1253527427482439e-07}. Best is trial 45 with value: 0.34904708530346723.
# regularization_factors, val_score: 0.349046:  30%|###       | 6/20 [00:00<00:01, 11.14it/s]
# Early stopping, best iteration is:
# [42]	valid_0's multi_logloss: 0.349056
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [56]	valid_0's multi_logloss: 0.351587
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [42]	valid_0's multi_logloss: 0.349047
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 0.349046:  30%|###       | 6/20 [00:00<00:01, 11.14it/s][I 2021-05-12 16:23:34,460] Trial 46 finished with value: 0.373581507432984 and parameters: {'lambda_l1': 5.709555046287916, 'lambda_l2': 4.522314010421975e-06}. Best is trial 45 with value: 0.34904708530346723.
# regularization_factors, val_score: 0.349046:  40%|####      | 8/20 [00:00<00:00, 12.13it/s][I 2021-05-12 16:23:34,531] Trial 47 finished with value: 0.34904644535459484 and parameters: {'lambda_l1': 1.8502469690373476e-08, 'lambda_l2': 1.4531906876075925e-06}. Best is trial 47 with value: 0.34904644535459484.
# regularization_factors, val_score: 0.349046:  40%|####      | 8/20 [00:00<00:00, 12.13it/s][I 2021-05-12 16:23:34,599] Trial 48 finished with value: 0.3490481853933383 and parameters: {'lambda_l1': 0.0003154595229945596, 'lambda_l2': 3.896839944180913e-05}. Best is trial 47 with value: 0.34904644535459484.
# regularization_factors, val_score: 0.349046:  45%|####5     | 9/20 [00:00<00:00, 12.13it/s]
# Early stopping, best iteration is:
# [73]	valid_0's multi_logloss: 0.373582
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [42]	valid_0's multi_logloss: 0.349046
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [42]	valid_0's multi_logloss: 0.349048
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [40]	valid_0's multi_logloss: 0.358159
# regularization_factors, val_score: 0.349046:  50%|#####     | 10/20 [00:00<00:00, 13.12it/s][I 2021-05-12 16:23:34,662] Trial 49 finished with value: 0.3581590733348253 and parameters: {'lambda_l1': 0.0023889273555827563, 'lambda_l2': 0.6366129023090409}. Best is trial 47 with value: 0.34904644535459484.
# regularization_factors, val_score: 0.349046:  50%|#####     | 10/20 [00:00<00:00, 13.12it/s][I 2021-05-12 16:23:34,716] Trial 50 finished with value: 0.34904643963856635 and parameters: {'lambda_l1': 1.467264735957174e-08, 'lambda_l2': 1.0812692075243581e-08}. Best is trial 50 with value: 0.34904643963856635.
# regularization_factors, val_score: 0.349046:  60%|######    | 12/20 [00:00<00:00, 14.43it/s][I 2021-05-12 16:23:34,774] Trial 51 finished with value: 0.349046439935314 and parameters: {'lambda_l1': 2.6442625983677556e-08, 'lambda_l2': 7.275719472512958e-08}. Best is trial 50 with value: 0.34904643963856635.
# regularization_factors, val_score: 0.349046:  60%|######    | 12/20 [00:00<00:00, 14.43it/s][I 2021-05-12 16:23:34,830] Trial 52 finished with value: 0.34904643965948096 and parameters: {'lambda_l1': 1.7545802550129493e-08, 'lambda_l2': 1.1673016222816983e-08}. Best is trial 50 with value: 0.34904643963856635.
# regularization_factors, val_score: 0.349046:  65%|######5   | 13/20 [00:00<00:00, 14.43it/s]
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [42]	valid_0's multi_logloss: 0.349046
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [42]	valid_0's multi_logloss: 0.349046
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [42]	valid_0's multi_logloss: 0.349046
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 0.349046:  70%|#######   | 14/20 [00:01<00:00, 15.30it/s][I 2021-05-12 16:23:34,888] Trial 53 finished with value: 0.3490464435951814 and parameters: {'lambda_l1': 7.525353795797874e-07, 'lambda_l2': 1.0856438995228176e-08}. Best is trial 50 with value: 0.34904643963856635.
# regularization_factors, val_score: 0.349046:  70%|#######   | 14/20 [00:01<00:00, 15.30it/s][I 2021-05-12 16:23:34,945] Trial 54 finished with value: 0.34904644559680154 and parameters: {'lambda_l1': 1.1787974385290238e-06, 'lambda_l2': 1.3286893607259766e-08}. Best is trial 50 with value: 0.34904643963856635.
# regularization_factors, val_score: 0.349046:  80%|########  | 16/20 [00:01<00:00, 15.19it/s][I 2021-05-12 16:23:35,022] Trial 55 finished with value: 0.3696967160512031 and parameters: {'lambda_l1': 4.3529398073584226e-07, 'lambda_l2': 5.378802362700422}. Best is trial 50 with value: 0.34904643963856635.
# regularization_factors, val_score: 0.349046:  80%|########  | 16/20 [00:01<00:00, 15.19it/s][I 2021-05-12 16:23:35,078] Trial 56 finished with value: 0.34904643961601073 and parameters: {'lambda_l1': 1.0739306788393445e-08, 'lambda_l2': 1.0186012581435399e-08}. Best is trial 56 with value: 0.34904643961601073.
# regularization_factors, val_score: 0.349046:  85%|########5 | 17/20 [00:01<00:00, 15.19it/s]
# Early stopping, best iteration is:
# [42]	valid_0's multi_logloss: 0.349046
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [42]	valid_0's multi_logloss: 0.349046
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [69]	valid_0's multi_logloss: 0.369697
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [42]	valid_0's multi_logloss: 0.349046
# regularization_factors, val_score: 0.349046:  90%|######### | 18/20 [00:01<00:00, 15.88it/s][I 2021-05-12 16:23:35,135] Trial 57 finished with value: 0.3490464659757028 and parameters: {'lambda_l1': 5.16266801028888e-06, 'lambda_l2': 1.4034291103250896e-07}. Best is trial 56 with value: 0.34904643961601073.
# regularization_factors, val_score: 0.349046:  90%|######### | 18/20 [00:01<00:00, 15.88it/s][I 2021-05-12 16:23:35,191] Trial 58 finished with value: 0.35299167229736983 and parameters: {'lambda_l1': 1.1482212094687406e-07, 'lambda_l2': 0.12345894458787801}. Best is trial 56 with value: 0.34904643961601073.
# regularization_factors, val_score: 0.349046: 100%|##########| 20/20 [00:01<00:00, 16.29it/s][I 2021-05-12 16:23:35,251] Trial 59 finished with value: 0.34904665750918623 and parameters: {'lambda_l1': 5.820281544836403e-06, 'lambda_l2': 4.73457080732831e-05}. Best is trial 56 with value: 0.34904643961601073.
# regularization_factors, val_score: 0.349046: 100%|##########| 20/20 [00:01<00:00, 14.34it/s]
# min_data_in_leaf, val_score: 0.349046:   0%|          | 0/5 [00:00<?, ?it/s]
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [42]	valid_0's multi_logloss: 0.349046
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [42]	valid_0's multi_logloss: 0.352992
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [42]	valid_0's multi_logloss: 0.349047
# Training until validation scores don't improve for 100 rounds
# min_data_in_leaf, val_score: 0.349046:   0%|          | 0/5 [00:00<?, ?it/s][I 2021-05-12 16:23:35,327] Trial 60 finished with value: 0.35440048269308344 and parameters: {'min_child_samples': 25}. Best is trial 60 with value: 0.35440048269308344.
# min_data_in_leaf, val_score: 0.349046:  40%|####      | 2/5 [00:00<00:00, 16.05it/s][I 2021-05-12 16:23:35,378] Trial 61 finished with value: 0.37774253627733717 and parameters: {'min_child_samples': 50}. Best is trial 60 with value: 0.35440048269308344.
# min_data_in_leaf, val_score: 0.347095:  40%|####      | 2/5 [00:00<00:00, 16.05it/s][I 2021-05-12 16:23:35,436] Trial 62 finished with value: 0.3470945980090998 and parameters: {'min_child_samples': 10}. Best is trial 62 with value: 0.3470945980090998.
# min_data_in_leaf, val_score: 0.347095:  80%|########  | 4/5 [00:00<00:00, 16.99it/s][I 2021-05-12 16:23:35,491] Trial 63 finished with value: 0.37730351924106365 and parameters: {'min_child_samples': 5}. Best is trial 62 with value: 0.3470945980090998.
# min_data_in_leaf, val_score: 0.347095:  80%|########  | 4/5 [00:00<00:00, 16.99it/s]
# Early stopping, best iteration is:
# [42]	valid_0's multi_logloss: 0.3544
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [47]	valid_0's multi_logloss: 0.377743
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [66]	valid_0's multi_logloss: 0.347095
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [37]	valid_0's multi_logloss: 0.377304
# Training until validation scores don't improve for 100 rounds
# min_data_in_leaf, val_score: 0.347095:  80%|########  | 4/5 [00:00<00:00, 16.99it/s][I 2021-05-12 16:23:35,551] Trial 64 finished with value: 0.38705407076552084 and parameters: {'min_child_samples': 100}. Best is trial 62 with value: 0.3470945980090998.
# min_data_in_leaf, val_score: 0.347095: 100%|##########| 5/5 [00:00<00:00, 16.71it/s]
# [I 2021-05-12 16:23:35,575] A new study created in memory with name: no-name-2b73b142-b22e-4447-a08f-941c83b89944
# feature_fraction, val_score: 0.686538:   0%|          | 0/7 [00:00<?, ?it/s][I 2021-05-12 16:23:35,667] Trial 0 finished with value: 0.6865384898809366 and parameters: {'feature_fraction': 0.8}. Best is trial 0 with value: 0.6865384898809366.
# feature_fraction, val_score: 0.686538:  29%|##8       | 2/7 [00:00<00:00, 12.34it/s][I 2021-05-12 16:23:35,740] Trial 1 finished with value: 0.6948246110689182 and parameters: {'feature_fraction': 0.4}. Best is trial 0 with value: 0.6865384898809366.
# feature_fraction, val_score: 0.686538:  29%|##8       | 2/7 [00:00<00:00, 12.34it/s]
# Early stopping, best iteration is:
# [87]	valid_0's multi_logloss: 0.387054
# accuracy: 0.4698996655518395
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [5]	valid_0's multi_logloss: 0.686538
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [4]	valid_0's multi_logloss: 0.694825
# feature_fraction, val_score: 0.686538:  29%|##8       | 2/7 [00:00<00:00, 12.34it/s][I 2021-05-12 16:23:35,850] Trial 2 finished with value: 0.6875691916515259 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 0 with value: 0.6865384898809366.
# feature_fraction, val_score: 0.683518:  57%|#####7    | 4/7 [00:00<00:00, 10.52it/s][I 2021-05-12 16:23:35,950] Trial 3 finished with value: 0.6835177137249488 and parameters: {'feature_fraction': 1.0}. Best is trial 3 with value: 0.6835177137249488.
# feature_fraction, val_score: 0.683518:  57%|#####7    | 4/7 [00:00<00:00, 10.52it/s]
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [4]	valid_0's multi_logloss: 0.687569
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [5]	valid_0's multi_logloss: 0.683518
# feature_fraction, val_score: 0.683518:  57%|#####7    | 4/7 [00:00<00:00, 10.52it/s][I 2021-05-12 16:23:36,046] Trial 4 finished with value: 0.6959928125096972 and parameters: {'feature_fraction': 0.5}. Best is trial 3 with value: 0.6835177137249488.
# feature_fraction, val_score: 0.681144:  86%|########5 | 6/7 [00:00<00:00, 10.78it/s][I 2021-05-12 16:23:36,130] Trial 5 finished with value: 0.6811438160891826 and parameters: {'feature_fraction': 0.6}. Best is trial 5 with value: 0.6811438160891826.
# feature_fraction, val_score: 0.681144:  86%|########5 | 6/7 [00:00<00:00, 10.78it/s]
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [4]	valid_0's multi_logloss: 0.695993
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [7]	valid_0's multi_logloss: 0.681144
# Training until validation scores don't improve for 100 rounds
# feature_fraction, val_score: 0.681144:  86%|########5 | 6/7 [00:00<00:00, 10.78it/s][I 2021-05-12 16:23:36,224] Trial 6 finished with value: 0.6883592328945553 and parameters: {'feature_fraction': 0.7}. Best is trial 5 with value: 0.6811438160891826.
# feature_fraction, val_score: 0.681144: 100%|##########| 7/7 [00:00<00:00, 10.81it/s]
# num_leaves, val_score: 0.681144:   0%|          | 0/20 [00:00<?, ?it/s][I 2021-05-12 16:23:36,309] Trial 7 finished with value: 0.6811438160891826 and parameters: {'num_leaves': 40}. Best is trial 7 with value: 0.6811438160891826.
# num_leaves, val_score: 0.681144:  10%|#         | 2/20 [00:00<00:01, 12.00it/s][I 2021-05-12 16:23:36,395] Trial 8 finished with value: 0.6811438160891826 and parameters: {'num_leaves': 25}. Best is trial 7 with value: 0.6811438160891826.
# num_leaves, val_score: 0.681144:  10%|#         | 2/20 [00:00<00:01, 12.00it/s]
# Early stopping, best iteration is:
# [4]	valid_0's multi_logloss: 0.688359
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [7]	valid_0's multi_logloss: 0.681144
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [7]	valid_0's multi_logloss: 0.681144
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.681144:  10%|#         | 2/20 [00:00<00:01, 12.00it/s][I 2021-05-12 16:23:36,492] Trial 9 finished with value: 0.6811438160891826 and parameters: {'num_leaves': 201}. Best is trial 7 with value: 0.6811438160891826.
# num_leaves, val_score: 0.681144:  20%|##        | 4/20 [00:00<00:01, 11.05it/s][I 2021-05-12 16:23:36,586] Trial 10 finished with value: 0.6811438160891826 and parameters: {'num_leaves': 154}. Best is trial 7 with value: 0.6811438160891826.
# num_leaves, val_score: 0.681144:  20%|##        | 4/20 [00:00<00:01, 11.05it/s][I 2021-05-12 16:23:36,673] Trial 11 finished with value: 0.6811438160891826 and parameters: {'num_leaves': 135}. Best is trial 7 with value: 0.6811438160891826.
# num_leaves, val_score: 0.681144:  25%|##5       | 5/20 [00:00<00:01, 11.05it/s]
# Early stopping, best iteration is:
# [7]	valid_0's multi_logloss: 0.681144
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [7]	valid_0's multi_logloss: 0.681144
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [7]	valid_0's multi_logloss: 0.681144
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.681144:  30%|###       | 6/20 [00:00<00:01, 10.97it/s][I 2021-05-12 16:23:36,770] Trial 12 finished with value: 0.6811438160891826 and parameters: {'num_leaves': 187}. Best is trial 7 with value: 0.6811438160891826.
# num_leaves, val_score: 0.681144:  30%|###       | 6/20 [00:00<00:01, 10.97it/s][I 2021-05-12 16:23:36,853] Trial 13 finished with value: 0.6811438160891826 and parameters: {'num_leaves': 174}. Best is trial 7 with value: 0.6811438160891826.
# num_leaves, val_score: 0.681144:  40%|####      | 8/20 [00:00<00:01, 11.08it/s][I 2021-05-12 16:23:36,947] Trial 14 finished with value: 0.6811438160891826 and parameters: {'num_leaves': 241}. Best is trial 7 with value: 0.6811438160891826.
# num_leaves, val_score: 0.681144:  40%|####      | 8/20 [00:00<00:01, 11.08it/s]
# Early stopping, best iteration is:
# [7]	valid_0's multi_logloss: 0.681144
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [7]	valid_0's multi_logloss: 0.681144
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [7]	valid_0's multi_logloss: 0.681144
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.681144:  40%|####      | 8/20 [00:00<00:01, 11.08it/s][I 2021-05-12 16:23:37,012] Trial 15 finished with value: 0.6857784016603284 and parameters: {'num_leaves': 9}. Best is trial 7 with value: 0.6811438160891826.
# num_leaves, val_score: 0.681144:  50%|#####     | 10/20 [00:00<00:00, 10.97it/s][I 2021-05-12 16:23:37,133] Trial 16 finished with value: 0.6811438160891826 and parameters: {'num_leaves': 122}. Best is trial 7 with value: 0.6811438160891826.
# num_leaves, val_score: 0.681144:  50%|#####     | 10/20 [00:00<00:00, 10.97it/s]
# Early stopping, best iteration is:
# [4]	valid_0's multi_logloss: 0.685778
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [7]	valid_0's multi_logloss: 0.681144
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.681144:  50%|#####     | 10/20 [00:01<00:00, 10.97it/s][I 2021-05-12 16:23:37,256] Trial 17 finished with value: 0.6811438160891826 and parameters: {'num_leaves': 72}. Best is trial 7 with value: 0.6811438160891826.
# num_leaves, val_score: 0.681144:  60%|######    | 12/20 [00:01<00:00, 10.39it/s][I 2021-05-12 16:23:37,345] Trial 18 finished with value: 0.6857784016603284 and parameters: {'num_leaves': 9}. Best is trial 7 with value: 0.6811438160891826.
# num_leaves, val_score: 0.681144:  60%|######    | 12/20 [00:01<00:00, 10.39it/s][I 2021-05-12 16:23:37,450] Trial 19 finished with value: 0.6811438160891826 and parameters: {'num_leaves': 55}. Best is trial 7 with value: 0.6811438160891826.
# num_leaves, val_score: 0.681144:  65%|######5   | 13/20 [00:01<00:00, 10.39it/s]
# Early stopping, best iteration is:
# [7]	valid_0's multi_logloss: 0.681144
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [4]	valid_0's multi_logloss: 0.685778
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [7]	valid_0's multi_logloss: 0.681144
# num_leaves, val_score: 0.681144:  70%|#######   | 14/20 [00:01<00:00, 10.24it/s][I 2021-05-12 16:23:37,546] Trial 20 finished with value: 0.6811438160891826 and parameters: {'num_leaves': 53}. Best is trial 7 with value: 0.6811438160891826.
# num_leaves, val_score: 0.681144:  70%|#######   | 14/20 [00:01<00:00, 10.24it/s][I 2021-05-12 16:23:37,654] Trial 21 finished with value: 0.6811438160891826 and parameters: {'num_leaves': 90}. Best is trial 7 with value: 0.6811438160891826.
# num_leaves, val_score: 0.681144:  75%|#######5  | 15/20 [00:01<00:00, 10.24it/s]
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [7]	valid_0's multi_logloss: 0.681144
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [7]	valid_0's multi_logloss: 0.681144
# num_leaves, val_score: 0.681144:  80%|########  | 16/20 [00:01<00:00, 10.27it/s][I 2021-05-12 16:23:37,740] Trial 22 finished with value: 0.6811438160891826 and parameters: {'num_leaves': 21}. Best is trial 7 with value: 0.6811438160891826.
# num_leaves, val_score: 0.681144:  80%|########  | 16/20 [00:01<00:00, 10.27it/s]
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [7]	valid_0's multi_logloss: 0.681144
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.681144:  80%|########  | 16/20 [00:01<00:00, 10.27it/s][I 2021-05-12 16:23:38,067] Trial 23 finished with value: 0.6811438160891826 and parameters: {'num_leaves': 33}. Best is trial 7 with value: 0.6811438160891826.
# num_leaves, val_score: 0.681144:  90%|######### | 18/20 [00:01<00:00,  7.62it/s][I 2021-05-12 16:23:38,151] Trial 24 finished with value: 0.6811438160891826 and parameters: {'num_leaves': 96}. Best is trial 7 with value: 0.6811438160891826.
# num_leaves, val_score: 0.681144:  90%|######### | 18/20 [00:01<00:00,  7.62it/s][I 2021-05-12 16:23:38,198] Trial 25 finished with value: 0.6852943515777874 and parameters: {'num_leaves': 5}. Best is trial 7 with value: 0.6811438160891826.
# num_leaves, val_score: 0.681144:  95%|#########5| 19/20 [00:01<00:00,  7.62it/s]
# Early stopping, best iteration is:
# [7]	valid_0's multi_logloss: 0.681144
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [7]	valid_0's multi_logloss: 0.681144
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [7]	valid_0's multi_logloss: 0.685294
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.681144: 100%|##########| 20/20 [00:02<00:00,  8.81it/s][I 2021-05-12 16:23:38,299] Trial 26 finished with value: 0.6811438160891826 and parameters: {'num_leaves': 47}. Best is trial 7 with value: 0.6811438160891826.
# num_leaves, val_score: 0.681144: 100%|##########| 20/20 [00:02<00:00,  9.65it/s]
# bagging, val_score: 0.681144:   0%|          | 0/10 [00:00<?, ?it/s][I 2021-05-12 16:23:38,370] Trial 27 finished with value: 0.6865860618483975 and parameters: {'bagging_fraction': 0.5867534273389056, 'bagging_freq': 5}. Best is trial 27 with value: 0.6865860618483975.
# bagging, val_score: 0.681144:  20%|##        | 2/10 [00:00<00:00, 13.67it/s][I 2021-05-12 16:23:38,450] Trial 28 finished with value: 0.6865860618483975 and parameters: {'bagging_fraction': 0.586875102023546, 'bagging_freq': 5}. Best is trial 27 with value: 0.6865860618483975.
# bagging, val_score: 0.681144:  20%|##        | 2/10 [00:00<00:00, 13.67it/s]
# Early stopping, best iteration is:
# [7]	valid_0's multi_logloss: 0.681144
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [4]	valid_0's multi_logloss: 0.686586
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [4]	valid_0's multi_logloss: 0.686586
# Training until validation scores don't improve for 100 rounds
# bagging, val_score: 0.681144:  20%|##        | 2/10 [00:00<00:00, 13.67it/s][I 2021-05-12 16:23:38,534] Trial 29 finished with value: 0.6928590581475618 and parameters: {'bagging_fraction': 0.4951318071708023, 'bagging_freq': 7}. Best is trial 27 with value: 0.6865860618483975.
# bagging, val_score: 0.681144:  40%|####      | 4/10 [00:00<00:00, 12.57it/s][I 2021-05-12 16:23:38,618] Trial 30 finished with value: 0.6965487027843265 and parameters: {'bagging_fraction': 0.6492424755818207, 'bagging_freq': 7}. Best is trial 27 with value: 0.6865860618483975.
# bagging, val_score: 0.681144:  40%|####      | 4/10 [00:00<00:00, 12.57it/s][I 2021-05-12 16:23:38,713] Trial 31 finished with value: 0.6932528033753116 and parameters: {'bagging_fraction': 0.8391147539180431, 'bagging_freq': 3}. Best is trial 27 with value: 0.6865860618483975.
# bagging, val_score: 0.681144:  50%|#####     | 5/10 [00:00<00:00, 12.57it/s]
# Early stopping, best iteration is:
# [8]	valid_0's multi_logloss: 0.692859
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [8]	valid_0's multi_logloss: 0.696549
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [6]	valid_0's multi_logloss: 0.693253
# Training until validation scores don't improve for 100 rounds
# bagging, val_score: 0.681144:  60%|######    | 6/10 [00:00<00:00, 11.97it/s][I 2021-05-12 16:23:38,794] Trial 32 finished with value: 0.690224258532299 and parameters: {'bagging_fraction': 0.5420609915596342, 'bagging_freq': 3}. Best is trial 27 with value: 0.6865860618483975.
# bagging, val_score: 0.681144:  60%|######    | 6/10 [00:00<00:00, 11.97it/s][I 2021-05-12 16:23:38,900] Trial 33 finished with value: 0.6931803588305983 and parameters: {'bagging_fraction': 0.8285572970248116, 'bagging_freq': 5}. Best is trial 27 with value: 0.6865860618483975.
# bagging, val_score: 0.681144:  80%|########  | 8/10 [00:00<00:00, 11.55it/s][I 2021-05-12 16:23:38,977] Trial 34 finished with value: 0.6898905653851513 and parameters: {'bagging_fraction': 0.6202438300423279, 'bagging_freq': 2}. Best is trial 27 with value: 0.6865860618483975.
# bagging, val_score: 0.681144:  80%|########  | 8/10 [00:00<00:00, 11.55it/s]
# Early stopping, best iteration is:
# [8]	valid_0's multi_logloss: 0.690224
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [8]	valid_0's multi_logloss: 0.69318
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [14]	valid_0's multi_logloss: 0.689891
# Training until validation scores don't improve for 100 rounds
# bagging, val_score: 0.681144:  80%|########  | 8/10 [00:00<00:00, 11.55it/s][I 2021-05-12 16:23:39,073] Trial 35 finished with value: 0.6963991491364911 and parameters: {'bagging_fraction': 0.9412628637957065, 'bagging_freq': 6}. Best is trial 27 with value: 0.6865860618483975.
# bagging, val_score: 0.681144: 100%|##########| 10/10 [00:00<00:00, 11.77it/s][I 2021-05-12 16:23:39,141] Trial 36 finished with value: 0.690409167726071 and parameters: {'bagging_fraction': 0.46254880910040874, 'bagging_freq': 3}. Best is trial 27 with value: 0.6865860618483975.
# bagging, val_score: 0.681144: 100%|##########| 10/10 [00:00<00:00, 11.91it/s]
# feature_fraction_stage2, val_score: 0.681144:   0%|          | 0/6 [00:00<?, ?it/s][I 2021-05-12 16:23:39,226] Trial 37 finished with value: 0.6876168978270344 and parameters: {'feature_fraction': 0.584}. Best is trial 37 with value: 0.6876168978270344.
# feature_fraction_stage2, val_score: 0.681144:  17%|#6        | 1/6 [00:00<00:00, 11.95it/s]
# Early stopping, best iteration is:
# [8]	valid_0's multi_logloss: 0.696399
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [21]	valid_0's multi_logloss: 0.690409
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [6]	valid_0's multi_logloss: 0.687617
# Training until validation scores don't improve for 100 rounds
# feature_fraction_stage2, val_score: 0.681144:  33%|###3      | 2/6 [00:00<00:00, 11.63it/s][I 2021-05-12 16:23:39,317] Trial 38 finished with value: 0.6871302203129694 and parameters: {'feature_fraction': 0.552}. Best is trial 38 with value: 0.6871302203129694.
# feature_fraction_stage2, val_score: 0.681144:  33%|###3      | 2/6 [00:00<00:00, 11.63it/s][I 2021-05-12 16:23:39,395] Trial 39 finished with value: 0.6959928125096972 and parameters: {'feature_fraction': 0.52}. Best is trial 38 with value: 0.6871302203129694.
# feature_fraction_stage2, val_score: 0.681144:  67%|######6   | 4/6 [00:00<00:00, 12.35it/s][I 2021-05-12 16:23:39,472] Trial 40 finished with value: 0.6895433772747508 and parameters: {'feature_fraction': 0.6799999999999999}. Best is trial 38 with value: 0.6871302203129694.
# feature_fraction_stage2, val_score: 0.681144:  67%|######6   | 4/6 [00:00<00:00, 12.35it/s]
# Early stopping, best iteration is:
# [8]	valid_0's multi_logloss: 0.68713
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [4]	valid_0's multi_logloss: 0.695993
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [4]	valid_0's multi_logloss: 0.689543
# Training until validation scores don't improve for 100 rounds
# feature_fraction_stage2, val_score: 0.681144:  67%|######6   | 4/6 [00:00<00:00, 12.35it/s][I 2021-05-12 16:23:39,555] Trial 41 finished with value: 0.6874149672140674 and parameters: {'feature_fraction': 0.6479999999999999}. Best is trial 38 with value: 0.6871302203129694.
# feature_fraction_stage2, val_score: 0.681144: 100%|##########| 6/6 [00:00<00:00, 12.63it/s][I 2021-05-12 16:23:39,626] Trial 42 finished with value: 0.6852224406019459 and parameters: {'feature_fraction': 0.616}. Best is trial 42 with value: 0.6852224406019459.
# feature_fraction_stage2, val_score: 0.681144: 100%|##########| 6/6 [00:00<00:00, 12.42it/s]
# regularization_factors, val_score: 0.681144:   0%|          | 0/20 [00:00<?, ?it/s][I 2021-05-12 16:23:39,698] Trial 43 finished with value: 0.682864591488768 and parameters: {'lambda_l1': 0.35478576143469076, 'lambda_l2': 0.5752908884076268}. Best is trial 43 with value: 0.682864591488768.
# ...
# regularization_factors, val_score: 1.051934:  15%|#5        | 3/20 [00:00<00:01,  9.57it/s][I 2021-05-12 16:45:44,566] Trial 45 finished with value: 1.0523110097920139 and parameters: {'lambda_l1': 0.010874549834355726, 'lambda_l2': 8.375345047776496e-05}. Best is trial 43 with value: 1.051934083424198.
# regularization_factors, val_score: 1.051934:  15%|#5        | 3/20 [00:00<00:01,  9.57it/s]
# Early stopping, best iteration is:
# [219]	valid_0's rmse: 1.05193
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.05385
# Early stopping, best iteration is:
# [157]	valid_0's rmse: 1.05231
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.05385
# Early stopping, best iteration is:
# [157]	valid_0's rmse: 1.05231
# regularization_factors, val_score: 1.051934:  20%|##        | 4/20 [00:00<00:01,  8.79it/s][I 2021-05-12 16:45:44,697] Trial 46 finished with value: 1.0524498731960692 and parameters: {'lambda_l1': 0.9220112326492892, 'lambda_l2': 1.1076451224084522e-07}. Best is trial 43 with value: 1.051934083424198.
# regularization_factors, val_score: 1.051934:  20%|##        | 4/20 [00:00<00:01,  8.79it/s]
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.05345
# Early stopping, best iteration is:
# [212]	valid_0's rmse: 1.05245
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 1.051934:  25%|##5       | 5/20 [00:00<00:01,  8.15it/s][I 2021-05-12 16:45:44,839] Trial 47 finished with value: 1.0523107791625117 and parameters: {'lambda_l1': 0.00038187445981747515, 'lambda_l2': 0.008524702756624026}. Best is trial 43 with value: 1.051934083424198.
# regularization_factors, val_score: 1.051934:  25%|##5       | 5/20 [00:00<00:01,  8.15it/s][I 2021-05-12 16:45:44,938] Trial 48 finished with value: 1.05215585921045 and parameters: {'lambda_l1': 1.4399089995140051e-06, 'lambda_l2': 0.0876336848716787}. Best is trial 43 with value: 1.051934083424198.
# regularization_factors, val_score: 1.051934:  30%|###       | 6/20 [00:00<00:01,  8.15it/s]
# [200]	valid_0's rmse: 1.05385
# Early stopping, best iteration is:
# [157]	valid_0's rmse: 1.05231
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.05306
# Early stopping, best iteration is:
# [157]	valid_0's rmse: 1.05216
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 1.051541:  35%|###5      | 7/20 [00:00<00:01,  8.36it/s][I 2021-05-12 16:45:45,071] Trial 49 finished with value: 1.051541020669905 and parameters: {'lambda_l1': 1.8731821806402997, 'lambda_l2': 3.7039366406648846e-06}. Best is trial 49 with value: 1.051541020669905.
# regularization_factors, val_score: 1.051541:  35%|###5      | 7/20 [00:00<00:01,  8.36it/s][I 2021-05-12 16:45:45,166] Trial 50 finished with value: 1.051707057937142 and parameters: {'lambda_l1': 0.1326851271286949, 'lambda_l2': 0.4561787162568204}. Best is trial 49 with value: 1.051541020669905.
# regularization_factors, val_score: 1.051541:  40%|####      | 8/20 [00:00<00:01,  8.36it/s]
# [200]	valid_0's rmse: 1.05225
# Early stopping, best iteration is:
# [212]	valid_0's rmse: 1.05154
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.05365
# Early stopping, best iteration is:
# [157]	valid_0's rmse: 1.05171
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 1.051541:  45%|####5     | 9/20 [00:01<00:01,  8.44it/s][I 2021-05-12 16:45:45,305] Trial 51 finished with value: 1.0521566931875053 and parameters: {'lambda_l1': 0.022248553270187352, 'lambda_l2': 0.0820620279560725}. Best is trial 49 with value: 1.051541020669905.
# regularization_factors, val_score: 1.051541:  50%|#####     | 10/20 [00:01<00:01,  8.67it/s][I 2021-05-12 16:45:45,409] Trial 52 finished with value: 1.0520328420073217 and parameters: {'lambda_l1': 1.666068851123606, 'lambda_l2': 3.279748796736691e-07}. Best is trial 49 with value: 1.051541020669905.
# regularization_factors, val_score: 1.051541:  50%|#####     | 10/20 [00:01<00:01,  8.67it/s]
# [200]	valid_0's rmse: 1.05306
# Early stopping, best iteration is:
# [157]	valid_0's rmse: 1.05216
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.05263
# Early stopping, best iteration is:
# [212]	valid_0's rmse: 1.05203
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.05385
# regularization_factors, val_score: 1.051541:  50%|#####     | 10/20 [00:01<00:01,  8.67it/s][I 2021-05-12 16:45:45,501] Trial 53 finished with value: 1.0523107485771597 and parameters: {'lambda_l1': 1.149024535428941e-06, 'lambda_l2': 4.285015257033628e-05}. Best is trial 49 with value: 1.051541020669905.
# regularization_factors, val_score: 1.051541:  60%|######    | 12/20 [00:01<00:00,  8.87it/s][I 2021-05-12 16:45:45,627] Trial 54 finished with value: 1.0524501294973996 and parameters: {'lambda_l1': 0.1665041078954003, 'lambda_l2': 6.351448475534898}. Best is trial 49 with value: 1.051541020669905.
# regularization_factors, val_score: 1.051541:  60%|######    | 12/20 [00:01<00:00,  8.87it/s]
# Early stopping, best iteration is:
# [157]	valid_0's rmse: 1.05231
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.05304
# Early stopping, best iteration is:
# [218]	valid_0's rmse: 1.05245
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.05301
# regularization_factors, val_score: 1.051541:  65%|######5   | 13/20 [00:01<00:00,  8.61it/s][I 2021-05-12 16:45:45,755] Trial 55 finished with value: 1.052199961492281 and parameters: {'lambda_l1': 9.049164560308213, 'lambda_l2': 8.295503408032742}. Best is trial 49 with value: 1.051541020669905.
# regularization_factors, val_score: 1.051541:  65%|######5   | 13/20 [00:01<00:00,  8.61it/s][I 2021-05-12 16:45:45,851] Trial 56 finished with value: 1.052310749174985 and parameters: {'lambda_l1': 3.1401183904989666e-05, 'lambda_l2': 6.622852285458667e-06}. Best is trial 49 with value: 1.051541020669905.
# regularization_factors, val_score: 1.051541:  75%|#######5  | 15/20 [00:01<00:00,  9.22it/s][I 2021-05-12 16:45:45,948] Trial 57 finished with value: 1.0523107525704776 and parameters: {'lambda_l1': 2.0226856991696887e-08, 'lambda_l2': 0.001667797457002003}. Best is trial 49 with value: 1.051541020669905.
# regularization_factors, val_score: 1.051541:  75%|#######5  | 15/20 [00:01<00:00,  9.22it/s]
# Early stopping, best iteration is:
# [219]	valid_0's rmse: 1.0522
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.05385
# Early stopping, best iteration is:
# [157]	valid_0's rmse: 1.05231
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.05385
# Early stopping, best iteration is:
# [157]	valid_0's rmse: 1.05231
# regularization_factors, val_score: 1.051541:  80%|########  | 16/20 [00:01<00:00,  9.09it/s][I 2021-05-12 16:45:46,063] Trial 58 finished with value: 1.0524398331857339 and parameters: {'lambda_l1': 0.10128321987451676, 'lambda_l2': 5.383889250442083e-06}. Best is trial 49 with value: 1.051541020669905.
# regularization_factors, val_score: 1.051541:  80%|########  | 16/20 [00:01<00:00,  9.09it/s][I 2021-05-12 16:45:46,161] Trial 59 finished with value: 1.0519002992738562 and parameters: {'lambda_l1': 0.22744119798501972, 'lambda_l2': 0.3376197239885085}. Best is trial 49 with value: 1.051541020669905.
# regularization_factors, val_score: 1.051541:  85%|########5 | 17/20 [00:01<00:00,  9.09it/s]
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.05358
# Early stopping, best iteration is:
# [157]	valid_0's rmse: 1.05244
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.05307
# Early stopping, best iteration is:
# [157]	valid_0's rmse: 1.0519
# regularization_factors, val_score: 1.051541:  90%|######### | 18/20 [00:02<00:00,  9.17it/s][I 2021-05-12 16:45:46,278] Trial 60 finished with value: 1.052310901046454 and parameters: {'lambda_l1': 0.006304493626155617, 'lambda_l2': 0.0005395527617720811}. Best is trial 49 with value: 1.051541020669905.
# regularization_factors, val_score: 1.051541:  95%|#########5| 19/20 [00:02<00:00,  9.25it/s][I 2021-05-12 16:45:46,383] Trial 61 finished with value: 1.0520880972836595 and parameters: {'lambda_l1': 7.757025410575626, 'lambda_l2': 1.2201666013168035e-08}. Best is trial 49 with value: 1.051541020669905.
# regularization_factors, val_score: 1.051541:  95%|#########5| 19/20 [00:02<00:00,  9.25it/s]
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.05385
# Early stopping, best iteration is:
# [157]	valid_0's rmse: 1.05231
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.05306
# Early stopping, best iteration is:
# [219]	valid_0's rmse: 1.05209
# regularization_factors, val_score: 1.051541: 100%|##########| 20/20 [00:02<00:00,  9.04it/s][I 2021-05-12 16:45:46,501] Trial 62 finished with value: 1.0523107567017709 and parameters: {'lambda_l1': 0.0003455712648508481, 'lambda_l2': 6.598480139200547e-06}. Best is trial 49 with value: 1.051541020669905.
# regularization_factors, val_score: 1.051541: 100%|##########| 20/20 [00:02<00:00,  8.85it/s]
# min_data_in_leaf, val_score: 1.051541:   0%|          | 0/5 [00:00<?, ?it/s]
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.05385
# Early stopping, best iteration is:
# [157]	valid_0's rmse: 1.05231
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.05364
# min_data_in_leaf, val_score: 1.051541:  20%|##        | 1/5 [00:00<00:00,  6.26it/s][I 2021-05-12 16:45:46,666] Trial 63 finished with value: 1.0524096857303564 and parameters: {'min_child_samples': 100}. Best is trial 63 with value: 1.0524096857303564.
# min_data_in_leaf, val_score: 1.051541:  40%|####      | 2/5 [00:00<00:00,  7.46it/s][I 2021-05-12 16:45:46,782] Trial 64 finished with value: 1.0546473489649475 and parameters: {'min_child_samples': 10}. Best is trial 63 with value: 1.0524096857303564.
# min_data_in_leaf, val_score: 1.051541:  40%|####      | 2/5 [00:00<00:00,  7.46it/s]
# Early stopping, best iteration is:
# [219]	valid_0's rmse: 1.05241
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.05552
# Early stopping, best iteration is:
# [158]	valid_0's rmse: 1.05465
# Training until validation scores don't improve for 100 rounds
# min_data_in_leaf, val_score: 1.051541:  60%|######    | 3/5 [00:00<00:00,  6.93it/s][I 2021-05-12 16:45:46,939] Trial 65 finished with value: 1.0538009850771914 and parameters: {'min_child_samples': 5}. Best is trial 63 with value: 1.0524096857303564.
# min_data_in_leaf, val_score: 1.050828:  80%|########  | 4/5 [00:00<00:00,  7.68it/s][I 2021-05-12 16:45:47,047] Trial 66 finished with value: 1.0508280843531947 and parameters: {'min_child_samples': 50}. Best is trial 66 with value: 1.0508280843531947.
# min_data_in_leaf, val_score: 1.050828:  80%|########  | 4/5 [00:00<00:00,  7.68it/s]
# [200]	valid_0's rmse: 1.05443
# Early stopping, best iteration is:
# [212]	valid_0's rmse: 1.0538
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.05182
# Early stopping, best iteration is:
# [218]	valid_0's rmse: 1.05083
# Training until validation scores don't improve for 100 rounds
# min_data_in_leaf, val_score: 1.050828: 100%|##########| 5/5 [00:00<00:00,  7.26it/s][I 2021-05-12 16:45:47,198] Trial 67 finished with value: 1.0518208091385357 and parameters: {'min_child_samples': 25}. Best is trial 66 with value: 1.0508280843531947.
# min_data_in_leaf, val_score: 1.050828: 100%|##########| 5/5 [00:00<00:00,  7.20it/s]
# [200]	valid_0's rmse: 1.05272
# Early stopping, best iteration is:
# [212]	valid_0's rmse: 1.05182
# rmse :  1.0018347394309806
# 1230 toto
# <ipython-input-5-7ab00576a4f2>:8: DtypeWarning: Columns (12,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   df_toto_preds = get_y_preds(toto_n, toto_kind)
# accuracy: 0.6012658227848101
# accuracy: 0.4651898734177215
# accuracy: 0.47468354430379744
# rmse :  1.3625448979164325
# rmse :  1.1083220258354016
# rmse :  1.1562136453063305
# 1231 toto
# <ipython-input-5-7ab00576a4f2>:8: DtypeWarning: Columns (12,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   df_toto_preds = get_y_preds(toto_n, toto_kind)
# accuracy: 0.5854430379746836
# accuracy: 0.5443037974683544
# accuracy: 0.46835443037974683
# rmse :  1.5481956219136663
# rmse :  1.0452217861421835
# rmse :  1.086750127320025
# 1232 toto
# <ipython-input-5-7ab00576a4f2>:8: DtypeWarning: Columns (12,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   df_toto_preds = get_y_preds(toto_n, toto_kind)
# accuracy: 0.569620253164557
# accuracy: 0.4936708860759494
# accuracy: 0.47151898734177217
# rmse :  1.3790576178038434
# rmse :  1.209284562154511
# rmse :  1.041478156168926
# 1233 toto
# <ipython-input-5-7ab00576a4f2>:8: DtypeWarning: Columns (12,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   df_toto_preds = get_y_preds(toto_n, toto_kind)
# accuracy: 0.620253164556962
# accuracy: 0.5221518987341772
# accuracy: 0.5221518987341772
# rmse :  1.4886579441075602
# rmse :  1.177501736053314
# rmse :  1.0236257341918393
# 1234 toto
# <ipython-input-5-7ab00576a4f2>:8: DtypeWarning: Columns (12,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   df_toto_preds = get_y_preds(toto_n, toto_kind)
# accuracy: 0.6139240506329114
# accuracy: 0.5379746835443038
# accuracy: 0.5
# rmse :  1.3675465573073171
# rmse :  1.0990147138746373
# rmse :  1.1820421781366721
# 1235 toto
# <ipython-input-5-7ab00576a4f2>:8: DtypeWarning: Columns (12,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   df_toto_preds = get_y_preds(toto_n, toto_kind)
# accuracy: 0.6170886075949367
# accuracy: 0.5158227848101266
# accuracy: 0.49050632911392406
# rmse :  1.4316995458106874
# rmse :  1.0246992482466957
# rmse :  1.166499739533801
# 1236 toto
# <ipython-input-5-7ab00576a4f2>:8: DtypeWarning: Columns (12,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   df_toto_preds = get_y_preds(toto_n, toto_kind)
# accuracy: 0.6265822784810127
# accuracy: 0.5253164556962026
# accuracy: 0.4810126582278481
# rmse :  1.4090412293244754
# rmse :  1.1355993652614045
# rmse :  1.0582874716175132
# 1237 toto
# <ipython-input-5-7ab00576a4f2>:8: DtypeWarning: Columns (12,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   df_toto_preds = get_y_preds(toto_n, toto_kind)
# accuracy: 0.6424050632911392
# accuracy: 0.5348101265822784
# accuracy: 0.5284810126582279
# rmse :  1.4477362403755252
# rmse :  1.0422015236704534
# rmse :  1.0912540752455375
# 1238 toto
# <ipython-input-5-7ab00576a4f2>:8: DtypeWarning: Columns (12,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   df_toto_preds = get_y_preds(toto_n, toto_kind)
# accuracy: 0.6044303797468354
# accuracy: 0.5253164556962026
# accuracy: 0.4936708860759494
# rmse :  1.4022921667230486
# rmse :  1.1286375836978617
# rmse :  1.1552019776959668
# 1239 toto
# <ipython-input-5-7ab00576a4f2>:8: DtypeWarning: Columns (12,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   df_toto_preds = get_y_preds(toto_n, toto_kind)
# accuracy: 0.5822784810126582
# accuracy: 0.5411392405063291
# accuracy: 0.5031645569620253
# rmse :  1.4081342534010857
# rmse :  1.0303124145441542
# rmse :  1.0655646451155443
# 1240 toto
# <ipython-input-5-7ab00576a4f2>:8: DtypeWarning: Columns (12,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   df_toto_preds = get_y_preds(toto_n, toto_kind)
# accuracy: 0.6329113924050633
# accuracy: 0.47468354430379744
# accuracy: 0.4873417721518987
# rmse :  1.4543222624838283
# rmse :  1.0885248704583677
# rmse :  1.1928081672041224
