# %%
from codes.scraping import scraping_all
from codes.marge import marge
from codes.simulation_toto import toto_simulator as simulator
import pandas as pd
import time
import os

def clear():
    # os.system('cls')
    for i in range(100):
        print('')

def display_df(df):
    df = df.copy()
    df = df.round(2)
    df_columns = df.columns
    for col in df_columns:
        max_len = 0
        val_list = []
        for i, row in df.iterrows():
            if max_len < len(str(row[col])):
                max_len = len(str(row[col]))
        for i, row in df.iterrows():
            add_n = max_len - len(str(row[col]))
            add_s = ''
            for j in range(add_n):
                add_s += '　'
            val = str(row[col]) + add_s
            val_list += [val]
        df[col] =  val_list
    print(df)
                
while True:
    clear()
    print('1 : totoシミュレータ ')
    print('2 : データを更新する')
    key = input('')

    if key == '2':
        clear()
        sa = scraping_all.scraping_all()
        sa.scraping_and_clean()
        marge.marge_csv()
    elif key == '1':
        clear()
        df_toto = pd.read_csv('data/marge/toto_info.csv', index_col=0).reset_index(drop = True)
        df_toto = df_toto[['第n回', '種別']].drop_duplicates().sort_values(['第n回','種別'] , ascending=False).reset_index(drop = True)
        display_df(df_toto[:10])
        print('')
        print('n と 種別を入力')
        toto_n = input('n : ')
        toto_kind = input('種別 : ')
        try:
            toto_n = int(toto_n)
        except:
            toto_n = 0
        if df_toto[(df_toto['第n回'] == toto_n) & (df_toto['種別'] == toto_kind)].shape[0] == 1:
            clear()
            toto_sim = simulator.toto_simulator(toto_n, toto_kind)
            clear()
            df = toto_sim.get_result()
            clear()
            display_df(df)
            key = input('')
            continue_fund = False
        else:
            pass
    else:
        pass
# Out:
# 1 : totoシミュレータ
# 2 : データを更新する
# 1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     第n回            種別
# 0  1244  toto
# 1  1244  mini toto-B組
# 2  1244  mini toto-A組
# 3  1243  toto
# 4  1243  mini toto-B組
# 5  1243  mini toto-A組
# 6  1242  toto
# 7  1242  mini toto-B組
# 8  1242  mini toto-A組
# 9  1241  toto
#
# n と 種別を入力
# n : 1244
# 種別 : 1243
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1 : totoシミュレータ
# 2 : データを更新する
# 1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     第n回            種別
# 0  1244  toto
# 1  1244  mini toto-B組
# 2  1244  mini toto-A組
# 3  1243  toto
# 4  1243  mini toto-B組
# 5  1243  mini toto-A組
# 6  1242  toto
# 7  1242  mini toto-B組
# 8  1242  mini toto-A組
# 9  1241  toto
#
# n と 種別を入力
# n : 1243
# 種別 : toto
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 前処理１を実行
# /Users/satouwataru/.pyenv/versions/anaconda3-2020.07/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# /Users/satouwataru/.pyenv/versions/anaconda3-2020.07/lib/python3.8/site-packages/pandas/core/frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#      第n回    種別       開催日          ホーム       アウェイ pred proba_0 proba_1 proba_2
# 0   1243  toto  20210605  ＦＣ東京　　　　　　　  湘南ベルマーレ　　    1    0.17    0.42    0.42
# 1   1243  toto  20210606  北海道コンサドーレ札幌  横浜Ｆ・マリノス　    1    0.17    0.42    0.42
# 2   1243  toto  20210606  鹿島アントラーズ　　　  清水エスパルス　　    1    0.17    0.42    0.42
# 3   1243  toto  20210606  ヴィッセル神戸　　　　  浦和レッズ　　　　    1    0.17    0.42    0.42
# 4   1243  toto  20210605  レノファ山口ＦＣ　　　  愛媛ＦＣ　　　　　    1    0.17    0.42    0.42
# 5   1243  toto  20210605  ヴァンフォーレ甲府　　  アルビレックス新潟    1    0.17    0.42    0.42
# 6   1243  toto  20210605  ギラヴァンツ北九州　　  ジュビロ磐田　　　    1    0.17    0.42    0.42
# 7   1243  toto  20210605  ブラウブリッツ秋田　　  ＦＣ琉球　　　　　    1    0.17    0.42    0.42
# 8   1243  toto  20210606  ツエーゲン金沢　　　　  大宮アルディージャ    1    0.17    0.42    0.42
# 9   1243  toto  20210606  栃木ＳＣ　　　　　　　  京都サンガF.C.    1    0.17    0.42    0.42
# 10  1243  toto  20210606  ジェフユナイテッド千葉  モンテディオ山形　    1    0.17    0.42    0.42
# 11  1243  toto  20210605  松本山雅ＦＣ　　　　　  ＦＣ町田ゼルビア　    1    0.17    0.42    0.42
# 12  1243  toto  20210605  ＳＣ相模原　　　　　　  Ｖ・ファーレン長崎    1    0.17    0.42    0.42
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-b292b095207f> in <module>
#      60             clear()
#      61             display_df(toto_sim.get_result())
# ---> 62             key = input('')
#      63             continue_fund = False
#      64         else:
#
# ~/.pyenv/versions/anaconda3-2020.07/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~/.pyenv/versions/anaconda3-2020.07/lib/python3.8/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
mini toto-A組
mini toto-A組
